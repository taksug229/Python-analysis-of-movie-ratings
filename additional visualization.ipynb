# %%
import pandas as pd
import os

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Takeshi Sugiyama\\Desktop\\Data Science\\Udemy\\Python A-Z\\Section 6'

# %%
mov = pd.read_csv("P4-Section6-Homework-Dataset.csv", encoding = 'latin1')

# %%
len(mov)
# Out:
# 608

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# Day of Week               608 non-null object
# Director                  608 non-null object
# Genre                     608 non-null object
# Movie Title               608 non-null object
# Release Date              608 non-null object
# Studio                    608 non-null object
# Adjusted Gross ($mill)    608 non-null object
# Budget ($mill)            608 non-null float64
# Gross ($mill)             608 non-null object
# IMDb Rating               608 non-null float64
# MovieLens Rating          608 non-null float64
# Overseas ($mill)          608 non-null object
# Overseas%                 608 non-null float64
# Profit ($mill)            608 non-null object
# Profit%                   608 non-null float64
# Runtime (min)             608 non-null int64
# US ($mill)                608 non-null float64
# Gross % US                608 non-null float64
# ...

# %%
mov.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
mov.columns = ["Day", "Direct","Genre","Title","ReleaseDate","Studio","AdjGross","Budget","Gross","IMDbRating","MovieLensRating","OverseasD","OverseasP","ProfitD","ProfitP","Runtime","USD","GrossPUS"]

# %%
mov.head()
# Out:
#       Day                   Direct   Genre              Title ReleaseDate  \
# 0  Friday                Brad Bird  action       Tomorrowland  22/05/2015
# 1  Friday              Scott Waugh  action     Need for Speed  14/03/2014
# 2  Friday           Patrick Hughes  action  The Expendables 3  15/08/2014
# 3  Friday  Phil Lord, Chris Miller  comedy     21 Jump Street  16/03/2012
# 4  Friday          Roland Emmerich  action   White House Down  28/06/2013
#
#                 Studio AdjGross  Budget  Gross  IMDbRating  MovieLensRating  \
# 0  Buena Vista Studios    202.1   170.0  202.1         6.7             3.26
# 1  Buena Vista Studios    204.2    66.0  203.3         6.6             2.97
# 2            Lionsgate    207.1   100.0  206.2         6.1             2.93
# 3                 Sony    208.8    42.0  201.6         7.2             3.62
# 4                 Sony    209.7   150.0  205.4         8.0             3.65
#
# ...

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# Day                608 non-null object
# Direct             608 non-null object
# Genre              608 non-null object
# Title              608 non-null object
# ReleaseDate        608 non-null object
# Studio             608 non-null object
# AdjGross           608 non-null object
# Budget             608 non-null float64
# Gross              608 non-null object
# IMDbRating         608 non-null float64
# MovieLensRating    608 non-null float64
# OverseasD          608 non-null object
# OverseasP          608 non-null float64
# ProfitD            608 non-null object
# ProfitP            608 non-null float64
# Runtime            608 non-null int64
# USD                608 non-null float64
# GrossPUS           608 non-null float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 85.6+ KB

# %%
mov.describe()
# Out:
#            Budget  IMDbRating  MovieLensRating   OverseasP       ProfitP  \
# count  608.000000  608.000000       608.000000  608.000000    608.000000
# mean    92.467928    6.923849         3.340378   57.698849    719.278783
# std     59.421407    0.925890         0.454071   12.334237   1942.807248
# min      0.600000    3.600000         1.490000   17.200000      7.700000
# 25%     45.000000    6.375000         3.037500   49.900000    201.850000
# 50%     80.000000    6.900000         3.365000   58.200000    338.550000
# 75%    130.000000    7.600000         3.672500   66.300000    650.100000
# max    300.000000    9.200000         4.500000  100.000000  41333.300000
#
#           Runtime         USD    GrossPUS
# count  608.000000  608.000000  608.000000
# mean   117.781250  167.135197   42.301151
# std     23.179122   92.465903   12.334237
# min     30.000000    0.000000    0.000000
# 25%    100.000000  106.950000   33.700000
# 50%    116.000000  141.700000   41.800000
# ...

# %%
vis1 = sns.factorplot(data = mov, x='Day', kind = 'count', size = 10)

# %%
#Filter data by Genre
#mov2 = mov[(mov.Genre == 'action') | (mov.Genre == 'adventure') | (mov.Genre == 'animation') | (mov.Genre == 'comedy') | (mov.Genre == 'drama')]
genre_filters = ['action','adventure','animation','comedy','drama']
mov2 = mov[mov.Genre.isin(genre_filters)]

# %%
#Filter data by Studio
#mov3 = mov2[(mov2.Studio =='Buena Vista Studios') | (mov2.Studio =='Sony') | (mov2.Studio =='Universal') | (mov2.Studio =='WB') | (mov2.Studio =='Paramount Pictures') | (mov2.Studio =='Fox')]
studio_filters = ['Buena Vista Studios','Fox','Paramount Pictures','Sony','Universal','WB']
mov3 = mov2[mov2.Studio.isin(studio_filters)]

# %%
# Checking how the filters worked
print (mov3.Genre.unique())
print(mov3.Studio.unique())
print (len(mov3))
# Out:
# ['action' 'comedy' 'adventure' 'animation' 'drama']
# ['Buena Vista Studios' 'Sony' 'Universal' 'WB' 'Paramount Pictures' 'Fox']
# 423

# %%
# Define the style
sns.set(style="dark", palette="muted", color_codes=True)

# Plot the boxsplots
ax = sns.boxplot(data=mov3, x='Genre', y='GrossPUS', orient='v', color='lightgray', showfliers=False)
plt.setp(ax.artists, alpha=0.5)

# Add in points to show each observation
sns.stripplot(x='Genre', y='GrossPUS', data=mov3, jitter=True, size=6, linewidth=0, hue = 'Studio', alpha=0.7)

ax.axes.set_title('Domestic Gross % by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel('Gross % US',fontsize=20)

# Define where to place the legend
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
